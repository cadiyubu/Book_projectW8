# %% [markdown]
# # Google Books API — Data Retrieval
#
# Second data source for the Book Recommendation System.
# Queries the Google Books Volumes API by subject, mirroring the 8 GoodReads Listopia categories scraped in `Webscraping_books.ipynb`.
# Output schema is aligned to `goodreads.csv` for a clean merge downstream.
#
# instructions on Google Books API available here: https://developers.google.com/books/docs/v1/reference/?apix=true

# %% [markdown]
# ## 1. Imports & Config

# %%
import os
import time
import logging
import requests
import pandas as pd
import yaml
from dotenv import load_dotenv
import sys
sys.path.insert(0, '.')
from functions import out_csv

# Load API key from .env
load_dotenv(override=True)
API_KEY = os.getenv('ggl_books_api')
assert API_KEY, 'API key not found — check .env for ggl_books_api'

# Logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s | %(levelname)s | %(message)s'
)
log = logging.getLogger(__name__)

YAML_PATH = '../config.yaml'

print(f'API key loaded: {API_KEY[:6]}...{API_KEY[-4:]}')
# Out:
# API key loaded: AIzaSy...yJ1A

# %% [markdown]
# ## 2. Query Configuration
#
# Each entry maps a human-readable list name (matching GoodReads `source_list` format)
# to a Google Books subject query term.
# Target: ~50 books per list × 8 lists = ~320 records (before deduplication).

# %%
# Maps source_list label → Google Books subject query string
LISTS = {
    'Best Books Ever':             'subject:fiction',
    'Books You Should Read':       'subject:classics',
    'Young Adult':                 'subject:"young adult"',
    'Books That Should Be Movies': 'subject:adventure',
    '20th Century Literature':     'subject:fiction',
    'Best Book Boyfriends':        'subject:romance',
    'Best Epic Fantasy':           'subject:fantasy',
    'Best Historical Fiction':     'subject:"historical fiction',
    'featured Google':'featured',
}

# Google Books API settings
BASE_URL    = 'https://www.googleapis.com/books/v1/volumes'
MAX_RESULTS = 40   # API hard cap per call
TARGET_PER_LIST = 100  # books to retrieve per list
DELAY_SECONDS = 1.0   # polite delay between calls

# %% [markdown]
# ## 3. Field Extraction Helper
#
# Extracts all required fields from a single `volumeInfo` dict.
# Returns `None` for any missing field — downstream cleaning handles nulls.
# Schema mirrors `goodreads.csv`: `book_name`, `book_url`, `source_list`, `author`,
# `rating`, `synopsis`, `pages`, `pub_date`, `genres`, `img_url`.

# %%
def extract_fields(item: dict, source_list: str) -> dict:
    """
    Parse a single Google Books API volume item into the project schema.

    Parameters
    ----------
    item : dict
        A single element from the API response 'items' list.
    source_list : str
        The list label to inject (mirrors GoodReads source_list values).

    Returns
    -------
    dict with keys matching goodreads.csv column names.
    Missing fields are None — not dropped here.
    """
    vi = item.get('volumeInfo', {})   #if it's missing, retunrs an empty dict instead of None so next get do not crash

    # authors: take first only, matching GoodReads single-author format
    authors = vi.get('authors', [])
    author  = authors[0] if authors else None

    # genres: pipe-separated string, matching GoodReads format
    categories = vi.get('categories', [])
    genres = '|'.join(categories) if categories else None

    # thumbnail image
    img_links = vi.get('imageLinks', {})
    img_url   = img_links.get('thumbnail') or img_links.get('smallThumbnail')

    return {
        'book_name'   : vi.get('title'),
        'book_url'    : vi.get('infoLink'),        # Google Books page (no list URL equivalent)
        'source_list' : source_list,
        'author'      : author,
        'rating'      : vi.get('averageRating'),   # float or None
        'synopsis'    : vi.get('description'),
        'pages'       : vi.get('pageCount'),       # int or None
        'pub_date'    : vi.get('publishedDate'),   # string, variable precision: YYYY / YYYY-MM / YYYY-MM-DD
        'genres'      : genres,
        'img_url'     : img_url,
        'data_source' : 'google_books',
    }

# %% [markdown]
# ## 4. Fetcher Function
#
# Queries the API for one list label, paginates up to `target` books,
# and returns a list of extracted record dicts.
# Implements exponential backoff on HTTP 429 (rate limit) and retries on 5xx errors.

# %%
def fetch_list(list_name: str, query: str, target: int = TARGET_PER_LIST) -> list:
    """
    Fetch up to `target` books for one list from the Google Books API.

    Pagination: startIndex increments by MAX_RESULTS each call.
    Stops early if the API returns fewer items than requested (end of results).
    Retries up to 3 times on 5xx errors with exponential backoff.
    Backs off 60 s on 429 (quota exceeded).

    Parameters
    ----------
    list_name : str   Human-readable label injected as source_list.
    query     : str   Subject search string sent to the API.
    target    : int   Maximum books to retrieve for this list.

    Returns
    -------
    list of dicts (one per book, schema from extract_fields)
    """
    records     = []
    start_index = 0

    while len(records) < target:
        params = {
            'q'          : query,
            'maxResults' : MAX_RESULTS,
            'startIndex' : start_index,
            'printType'  : 'books',
            'langRestrict': 'en',
            'key'        : API_KEY,
        }

        # Retry loop for transient server errors
        for attempt in range(3):
            try:
                resp = requests.get(BASE_URL, params=params, timeout=10)

                if resp.status_code == 429:
                    log.warning('Rate limit hit — sleeping 60 s')
                    time.sleep(60)
                    continue

                if resp.status_code >= 500:
                    wait = 2 ** attempt
                    log.warning(f'Server error {resp.status_code} — retry {attempt+1}/3 in {wait}s')
                    time.sleep(wait)
                    continue

                resp.raise_for_status()
                break  # success

            except requests.exceptions.RequestException as e:
                log.error(f'Request failed: {e}')
                if attempt == 2:
                    log.error(f'Giving up on list "{list_name}" at startIndex={start_index}')
                    return records
                time.sleep(2 ** attempt)

        data  = resp.json()
        items = data.get('items', [])

        if not items:
            log.info(f'[{list_name}] No more results at startIndex={start_index}')
            break

        for item in items:
            records.append(extract_fields(item, list_name))
            if len(records) >= target:
                break

        log.info(f'[{list_name}] Fetched {len(records)} / {target}')

        # Stop if API returned fewer than requested (end of result set)

        start_index += len(items)

        time.sleep(DELAY_SECONDS)

    return records

# %% [markdown]
# ## 5. Pilot Run — Measure Rating Coverage
#
# Fetch 40 books from the first list only.
# Goal: measure `averageRating` null-rate before committing to full run.
# Decision rule: if null-rate > 60%, the rating column is too sparse to be useful — flag and decide.

# %%
#testing API 503 error
params = {
    'q'           : 'featured',
    'maxResults'  : 40,
    'startIndex'  : 0,
    'printType'   : 'books',
    'langRestrict': 'en',
    'key'         : API_KEY,
}
resp = requests.get(BASE_URL, params=params, timeout=10)
data = resp.json()
print(resp.status_code)
print('totalItems:', data.get('totalItems'))
print('items returned:', len(data.get('items', [])))
# Out:
# 200
# totalItems: 300
# items returned: 20

# %%
# Pilot: first list only
pilot_list_name  = list(LISTS.keys())[0]
pilot_query      = LISTS[pilot_list_name]

log.info(f'Pilot run: "{pilot_list_name}" → query: "{pilot_query}"')
pilot_records = fetch_list(pilot_list_name, pilot_query, target=40)

pilot_df = pd.DataFrame(pilot_records)

# Rating null-rate
null_rate = pilot_df['rating'].isna().mean()
print(f'\nPilot results: {len(pilot_df)} books')
print(f'Rating null-rate: {null_rate:.1%}')
print(f'\nSample (5 rows):')
pilot_df[['book_name', 'author', 'rating', 'genres', 'pages', 'pub_date']].head()
# Out:
# 2026-07-10 10:08:12,075 | INFO | Pilot run: "Best Books Ever" → query: "subject:fiction"
# 2026-07-10 10:08:12,765 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:08:14,844 | INFO | [Best Books Ever] Fetched 20 / 40
# 2026-07-10 10:08:16,657 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:08:18,479 | INFO | [Best Books Ever] Fetched 40 / 40
# Pilot results: 40 books
# Rating null-rate: 95.0%
#
# Sample (5 rows):
#                                      book_name           author  rating  \
# 0                                   Persuasion      Jane Austen     NaN
# 1                          The Face of Another         Kōbō Abe     NaN
# 2                                 Oliver Twist  Charles Dickens     NaN
# 3           The Happy Prince and Other Stories      Oscar Wilde     NaN
# 4  Sense and Sensibility - Illustrated Edition      Jane Austen     NaN
#
#     genres  pages    pub_date
# 0  Fiction    260  2026-01-01
# 1  Fiction    260        1992
# 2  Fiction    220  2019-01-01
# 3  Fiction    105  2019-06-28
# 4  Fiction    579  2017-10-23

# %% [markdown]
# ## 6. Full Fetch — All Lists
#
# Run only after reviewing pilot results above.
# Iterates all lists, collects records, concatenates into a single DataFrame.

# %%
all_records = []

for list_name, query in LISTS.items():
    log.info(f'--- Starting list: {list_name} ---')
    records = fetch_list(list_name, query, target=TARGET_PER_LIST)
    all_records.extend(records)
    log.info(f'List complete: {len(records)} books retrieved')
    time.sleep(DELAY_SECONDS)

google_books_df = pd.DataFrame(all_records)
print(f'\nTotal records fetched: {len(google_books_df)}')
google_books_df.head(3)
# Out:
# 2026-07-10 10:26:32,354 | INFO | --- Starting list: Best Books Ever ---
# 2026-07-10 10:26:32,576 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:26:34,689 | INFO | [Best Books Ever] Fetched 20 / 100
# 2026-07-10 10:26:36,274 | INFO | [Best Books Ever] Fetched 40 / 100
# 2026-07-10 10:26:38,579 | INFO | [Best Books Ever] Fetched 60 / 100
# 2026-07-10 10:26:40,221 | INFO | [Best Books Ever] Fetched 80 / 100
# 2026-07-10 10:26:42,370 | INFO | [Best Books Ever] Fetched 100 / 100
# 2026-07-10 10:26:43,378 | INFO | List complete: 100 books retrieved
# 2026-07-10 10:26:44,384 | INFO | --- Starting list: Books You Should Read ---
# 2026-07-10 10:26:45,540 | INFO | [Books You Should Read] Fetched 20 / 100
# 2026-07-10 10:26:47,693 | INFO | [Books You Should Read] Fetched 40 / 100
# 2026-07-10 10:26:49,742 | INFO | [Books You Should Read] Fetched 60 / 100
# 2026-07-10 10:26:51,964 | INFO | [Books You Should Read] Fetched 80 / 100
# 2026-07-10 10:26:53,198 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:26:54,458 | WARNING | Server error 503 — retry 2/3 in 2s
# 2026-07-10 10:26:57,114 | INFO | [Books You Should Read] Fetched 100 / 100
# 2026-07-10 10:26:58,120 | INFO | List complete: 100 books retrieved
# 2026-07-10 10:26:59,125 | INFO | --- Starting list: Young Adult ---
# 2026-07-10 10:27:00,389 | INFO | [Young Adult] Fetched 20 / 100
# 2026-07-10 10:27:02,462 | INFO | [Young Adult] Fetched 40 / 100
# 2026-07-10 10:27:03,975 | INFO | [Young Adult] Fetched 60 / 100
# 2026-07-10 10:27:06,001 | INFO | [Young Adult] Fetched 80 / 100
# 2026-07-10 10:27:08,173 | INFO | [Young Adult] Fetched 100 / 100
# 2026-07-10 10:27:09,181 | INFO | List complete: 100 books retrieved
# 2026-07-10 10:27:10,186 | INFO | --- Starting list: Books That Should Be Movies ---
# 2026-07-10 10:27:11,006 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:27:12,781 | INFO | [Books That Should Be Movies] Fetched 20 / 100
# 2026-07-10 10:27:14,622 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:27:15,858 | WARNING | Server error 503 — retry 2/3 in 2s
# 2026-07-10 10:27:19,123 | INFO | [Books That Should Be Movies] Fetched 40 / 100
# 2026-07-10 10:27:20,460 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:27:22,101 | INFO | [Books That Should Be Movies] Fetched 60 / 100
# 2026-07-10 10:27:23,788 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:27:25,033 | WARNING | Server error 503 — retry 2/3 in 2s
# 2026-07-10 10:27:27,697 | WARNING | Server error 503 — retry 3/3 in 4s
# 2026-07-10 10:27:31,701 | INFO | [Books That Should Be Movies] No more results at startIndex=60
# 2026-07-10 10:27:31,705 | INFO | List complete: 60 books retrieved
# 2026-07-10 10:27:32,713 | INFO | --- Starting list: 20th Century Literature ---
# 2026-07-10 10:27:33,403 | INFO | [20th Century Literature] Fetched 20 / 100
# 2026-07-10 10:27:35,475 | INFO | [20th Century Literature] Fetched 40 / 100
# 2026-07-10 10:27:36,712 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:27:38,483 | WARNING | Server error 503 — retry 2/3 in 2s
# 2026-07-10 10:27:41,249 | INFO | [20th Century Literature] Fetched 60 / 100
# 2026-07-10 10:27:42,481 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:27:44,080 | INFO | [20th Century Literature] Fetched 80 / 100
# 2026-07-10 10:27:45,340 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:27:47,431 | INFO | [20th Century Literature] Fetched 100 / 100
# 2026-07-10 10:27:48,441 | INFO | List complete: 100 books retrieved
# 2026-07-10 10:27:49,446 | INFO | --- Starting list: Best Book Boyfriends ---
# 2026-07-10 10:27:50,396 | INFO | [Best Book Boyfriends] Fetched 20 / 100
# 2026-07-10 10:27:52,513 | INFO | [Best Book Boyfriends] Fetched 40 / 100
# 2026-07-10 10:27:54,358 | INFO | [Best Book Boyfriends] Fetched 60 / 100
# 2026-07-10 10:27:56,096 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:27:58,145 | INFO | [Best Book Boyfriends] Fetched 80 / 100
# 2026-07-10 10:27:59,988 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:28:01,206 | WARNING | Server error 503 — retry 2/3 in 2s
# 2026-07-10 10:28:03,981 | WARNING | Server error 503 — retry 3/3 in 4s
# 2026-07-10 10:28:07,985 | INFO | [Best Book Boyfriends] No more results at startIndex=80
# 2026-07-10 10:28:07,989 | INFO | List complete: 80 books retrieved
# 2026-07-10 10:28:08,992 | INFO | --- Starting list: Best Epic Fantasy ---
# 2026-07-10 10:28:09,470 | INFO | [Best Epic Fantasy] Fetched 20 / 100
# 2026-07-10 10:28:11,614 | INFO | [Best Epic Fantasy] Fetched 40 / 100
# 2026-07-10 10:28:13,407 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:28:15,142 | WARNING | Server error 503 — retry 2/3 in 2s
# 2026-07-10 10:28:17,704 | INFO | [Best Epic Fantasy] Fetched 60 / 100
# 2026-07-10 10:28:19,549 | INFO | [Best Epic Fantasy] Fetched 80 / 100
# 2026-07-10 10:28:21,186 | INFO | [Best Epic Fantasy] Fetched 100 / 100
# 2026-07-10 10:28:22,194 | INFO | List complete: 100 books retrieved
# 2026-07-10 10:28:23,200 | INFO | --- Starting list: Best Historical Fiction ---
# 2026-07-10 10:28:23,439 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:28:25,477 | INFO | [Best Historical Fiction] Fetched 20 / 100
# 2026-07-10 10:28:26,715 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:28:28,413 | INFO | [Best Historical Fiction] No more results at startIndex=20
# 2026-07-10 10:28:28,417 | INFO | List complete: 20 books retrieved
# 2026-07-10 10:28:29,422 | INFO | --- Starting list: featured Google ---
# 2026-07-10 10:28:29,675 | WARNING | Server error 503 — retry 1/3 in 1s
# 2026-07-10 10:28:31,797 | INFO | [featured Google] Fetched 20 / 100
# 2026-07-10 10:28:33,414 | INFO | [featured Google] Fetched 40 / 100
# 2026-07-10 10:28:35,001 | INFO | [featured Google] Fetched 60 / 100
# 2026-07-10 10:28:37,160 | INFO | [featured Google] Fetched 80 / 100
# 2026-07-10 10:28:39,210 | INFO | [featured Google] Fetched 100 / 100
# 2026-07-10 10:28:40,216 | INFO | List complete: 100 books retrieved
# Total records fetched: 760
#              book_name                                           book_url  \
# 0           Persuasion  https://play.google.com/store/books/details?id...
# 1  The Face of Another  http://books.google.de/books?id=_DYNAQAAMAAJ&d...
# 2         Oliver Twist  https://play.google.com/store/books/details?id...
#
#        source_list           author  rating  \
# 0  Best Books Ever      Jane Austen     NaN
# 1  Best Books Ever         Kōbō Abe     NaN
# 2  Best Books Ever  Charles Dickens     NaN
#
#                                             synopsis  pages    pub_date  \
# 0  Discover the timeless allure of love and secon...  260.0  2026-01-01
# 1  The Japanese novelist Kobo Abe has often been ...  260.0        1992
# 2  JAICO ILLUSTARTED CLASSICS SERIES is a collect...  220.0  2019-01-01
#
#     genres                                            img_url   data_source
# 0  Fiction  http://books.google.com/books/content?id=UrrTE...  google_books
# 1  Fiction                                                NaN  google_books
# 2  Fiction  http://books.google.com/books/content?id=3oSqD...  google_books

# %% [markdown]
# ## 7. Basic Validation & Deduplication
#
# Check shape, null counts, and deduplicate on `book_name` + `author`.
# This is a sanity check only — full cleaning happens in the cleaning notebook.

# %%
print('=== Shape before dedup ===')
print(google_books_df.shape)

print('\n=== Null counts ===')
print(google_books_df.isna().sum())

print('\n=== Rating distribution ===')
print(google_books_df['rating'].describe())

# Deduplicate: same book can appear across multiple list queries
before = len(google_books_df)
google_books_df = google_books_df.drop_duplicates(subset=['book_name', 'author'])
after = len(google_books_df)
print(f'\nDuplicates removed: {before - after} | Remaining: {after}')
# Out:
# === Shape before dedup ===
# (760, 11)
#
# === Null counts ===
# book_name        0
# book_url         0
# source_list      0
# author          79
# rating         684
# synopsis       193
# pages           41
# pub_date        12
# genres         137
# img_url        160
# data_source      0
# dtype: int64
#
# === Rating distribution ===
# count    76.000000
# mean      4.203947
# std       0.849226
# min       1.000000
# 25%       4.000000
# 50%       4.500000
# 75%       5.000000
# max       5.000000
# Name: rating, dtype: float64
#
# Duplicates removed: 137 | Remaining: 623

# %% [markdown]
# ## 8. Save to Raw CSV
#
# Saves to `data/raw/google_books.csv` via `out_csv()` from `functions.py`.
# Requires `config.yaml` to have the output path defined under the correct key.

# %%
out_csv(
    df                  = google_books_df,
    yaml_path           = YAML_PATH,
    output_section_yaml = 'raw_data',
    file_name           = 'raw_api'
)

print(f'Saved {len(google_books_df)} records.')
# Out:
# File saved to: ../data/raw/google_books.csv
# Saved 623 records.
